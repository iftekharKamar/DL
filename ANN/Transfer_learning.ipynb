# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np

import cv2
import os
import PIL.Image as Image

import tensorflow_hub as hub
# Out:
# WARNING:tensorflow:From c:\Users\Iftekhar\OneDrive\Desktop\Iftekhar\DL\ANN\py310env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# c:\Users\Iftekhar\OneDrive\Desktop\Iftekhar\DL\ANN\py310env\lib\site-packages\tensorflow_hub\__init__.py:61: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version

# %%
classifier = tf.keras.Sequential([
    hub.KerasLayer(
        "https://tfhub.dev/google/tf2-preview/mobilenet_v2/classification/4",
        input_shape=(224, 224, 3),
        trainable=False
    )
])

classifier.build([None, 224, 224, 3])
classifier.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer_1 (KerasLayer)  (None, 1001)              3540265
#
# =================================================================
# Total params: 3540265 (13.51 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 3540265 (13.51 MB)
# _________________________________________________________________
